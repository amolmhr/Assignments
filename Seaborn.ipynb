# %% [markdown]
# <a href="https://colab.research.google.com/github/amolmhr/Assignments/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# https://seaborn.pydata.org/tutorial/categorical.html

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe(include="all")
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
sns.displot(iris,x="sepal_length",binwidth=0.2)

# %%
sns.displot(iris,x="sepal_length",binwidth=0.2,hue="species")

# %%
sns.displot(iris,x="sepal_length",binwidth=0.2,hue="species",col="species")

# %%
sns.displot(iris,x="sepal_length",hue="species",col="species",kind="kde")

# %%
sns.displot(iris,x="sepal_length",hue="species",kind="kde")

# %%
sns.catplot(data=iris,x="species",y="sepal_length",kind="box")

# %%
sns.catplot(data=iris,y="species",x="sepal_length",kind="box")

# %%
sns.relplot(data=iris,x="sepal_length",y="petal_length",kind="scatter",hue="species")

# %%
fig,ax = plt.subplots(2,2,figsize=(10,5))
sns.scatterplot(data=iris,x="sepal_length",y="petal_length",hue="species",ax=ax[0][0])
sns.boxplot(data=iris,y="species",x="sepal_length",ax =ax [0][1])
sns.boxplot(data=iris,y="species",x="petal_length",ax =ax [1][0])
sns.boxplot(data=iris,y="species",x="sepal_width",ax =ax [1][1])
plt.tight_layout()

# %%
# Seaborn Mutivariate

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("https://raw.githubusercontent.com/AIP-BITS/DataViz/main/DataViz/Seaborn/spotify.csv",parse_dates=True,index_col="Date")
data
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2017-01-06 to 2018-01-09
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Shape of You              366 non-null    int64
#  1   Despacito                 359 non-null    float64
#  2   Something Just Like This  319 non-null    float64
#  3   HUMBLE.                   282 non-null    float64
#  4   Unforgettable             275 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 17.2 KB

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=data)
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=data['Shape of You'],label="Shape of You")
sns.lineplot(data=data['Despacito'],label="Despacito")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
data2= pd.read_csv("https://raw.githubusercontent.com/AIP-BITS/DataViz/main/DataViz/Seaborn/museum_visitors.csv",parse_dates=True,index_col="Date")
data2
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
# 2014-06-01        29487              5751                     2121
# 2014-07-01        32378              5406                     2239
# 2014-08-01        37680              8619                     1769
# 2014-09-01        28473             61192                     1073
# 2014-10-01        27995              6488                     1979
# 2014-11-01        25691              4189                     2404
# 2014-12-01        18754              4339                     1319
# 2015-01-01        20438              3858                     1823
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 59 entries, 2014-01-01 to 2018-11-01
# Data columns (total 4 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Avila Adobe                           59 non-null     int64
#  1   Firehouse Museum                      59 non-null     int64
#  2   Chinese American Museum               59 non-null     int64
#  3   America Tropical Interpretive Center  59 non-null     int64
# dtypes: int64(4)
# memory usage: 2.3 KB

# %%
sns.lineplot(data=data2)
# Out:
# <Axes: xlabel='Date'>

# %%
data_new.Date=data_new.Date.astype('datetime64')

# %%
data_flight=pd.read_csv("https://raw.githubusercontent.com/AIP-BITS/DataViz/main/DataViz/Seaborn/flight_delays.csv")
data_flight
# Out:
#     Month        AA        AS         B6        DL         EV         F9  \
# 0       1  6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 1       2  7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 2       3  6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 3       4  4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 4       5  5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 5       6  8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 6       7  3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 7       8  3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 8       9 -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 9      10 -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 10     11  0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 11     12  4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
# @title Month vs AA

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Month']
  ys = series['AA']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = data_flight.sort_values('Month', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Month')
_ = plt.ylabel('AA')

# %%
sns.lineplot("data_flight")
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
sns.barplot(data=data_flight,x=data_flight.Month,y=data_flight.NK,color="grey")
plt.axhline(y=15,color="red",linestyle="--")

clrs=["grey" if (x<15) else "red" for x in data_flight.NK]
sns.barplot(x=data_flight.Month,y=data_flight.NK,palette=clrs)
# Out:
# <ipython-input-50-cc3d45b8563e>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data_flight.Month,y=data_flight.NK,palette=clrs)
# <Axes: xlabel='Month', ylabel='NK'>

# %%
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
sns.lineplot(data=data_flight)
# Out:
# <Axes: >

# %%
sns.barplot(data=data_flight)
# Out:
# <Axes: >

# %%
iris=sns.load_dataset('iris')
sns.jointplot(data=iris,x="sepal_length",y="petal_length",hue="species")

# %%
sns.pairplot(data=iris,hue="species")

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="time",style="smoker",size="size")
